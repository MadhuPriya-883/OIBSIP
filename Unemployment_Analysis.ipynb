# %% [markdown]
# # **Task 2** **Unemployment** **Analysis** **with** **Python**

# %% [markdown]
# **Importing** **libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# **Loading** **Dataset**

# %%
df=pd.read_csv("https://github.com/MadhuPriya-883/OIBSIP/raw/main/Unemployment_Rate_upto_11_2020.csv")
df = pd.read_csv("https://github.com/MadhuPriya-883/OIBSIP/raw/main/Unemployment%20in%20India.csv")
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df.sample(8)
# Out:
#                States         Date Frequency  Estimated Unemployment Rate  \
# 492           Haryana   30-04-2020   Monthly                        46.89
# 305           Tripura   30-06-2019   Monthly                        26.64
# 120  Himachal Pradesh   31-05-2020   Monthly                        25.64
# 334       Uttarakhand   31-07-2019   Monthly                         5.74
# 478           Gujarat   30-04-2020   Monthly                        25.94
# 449             Delhi   31-01-2020   Monthly                        22.45
# 99            Haryana   31-10-2019   Monthly                        24.17
# 480           Gujarat   30-06-2020   Monthly                         4.54
#
#      Estimated Employed  Estimated Labour Participated Rate Region  Day Month  \
# 492           1606580.0                               35.48  Urban   30    04
# 305           1107013.0                               67.40  Rural   30    06
# ...

# %%
df.shape
# Out:
# (768, 10)

# %%
print("Rows" ,df.shape[0])
print("Colums" ,df.shape[1])
# Out:
# Rows 768
# Colums 10

# %%
df.isnull()
# Out:
#      States   Date  Frequency  Estimated Unemployment Rate  \
# 0     False  False      False                        False
# 1     False  False      False                        False
# 2     False  False      False                        False
# 3     False  False      False                        False
# 4     False  False      False                        False
# ..      ...    ...        ...                          ...
# 763    True   True       True                         True
# 764    True   True       True                         True
# 765    True   True       True                         True
# 766    True   True       True                         True
# 767    True   True       True                         True
#
#      Estimated Employed  Estimated Labour Participated Rate  Region    Day  \
# 0                 False                               False   False  False
# 1                 False                               False   False  False
# ...

# %%
df.isnull().sum()
# Out:
# States                                28
# Date                                  28
# Frequency                             28
# Estimated Unemployment Rate           28
# Estimated Employed                    28
# Estimated Labour Participated Rate    28
# Region                                28
# Day                                   28
# Month                                 28
# Year                                  28
# dtype: int64

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
df.info
# Out:
# <bound method DataFrame.info of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763     True
# 764     True
# 765     True
# 766     True
# 767     True
# Length: 768, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 27

# %%
df.dtypes
# Out:
# Region                                       object
#  Date                                        object
#  Frequency                                   object
#  Estimated Unemployment Rate (%)            float64
#  Estimated Employed                         float64
#  Estimated Labour Participation Rate (%)    float64
# Area                                         object
# dtype: object

# %%
df.columns=['States','Date','Frequency','Estimated Unemployment Rate','Estimated Employed','Estimated Labour Participated Rate','Region']
df
# Out:
#              States         Date Frequency  Estimated Unemployment Rate  \
# 0    Andhra Pradesh   31-05-2019   Monthly                         3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                         3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                         3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                         3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                         5.17
# ..              ...          ...       ...                          ...
# 763             NaN          NaN       NaN                          NaN
# 764             NaN          NaN       NaN                          NaN
# 765             NaN          NaN       NaN                          NaN
# 766             NaN          NaN       NaN                          NaN
# 767             NaN          NaN       NaN                          NaN
#
#      Estimated Employed  Estimated Labour Participated Rate Region
# ...

# %%
print(df)
# Out:
#              States         Date Frequency  Estimated Unemployment Rate  \
# 0    Andhra Pradesh   31-05-2019   Monthly                         3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                         3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                         3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                         3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                         5.17
# ..              ...          ...       ...                          ...
# 763             NaN          NaN       NaN                          NaN
# 764             NaN          NaN       NaN                          NaN
# 765             NaN          NaN       NaN                          NaN
# 766             NaN          NaN       NaN                          NaN
# 767             NaN          NaN       NaN                          NaN
#
#      Estimated Employed  Estimated Labour Participated Rate Region
# ...

# %%
df[['Day','Month','Year']]=df['Date'].str.split('-',expand=True)
df
# Out:
#              States         Date Frequency  Estimated Unemployment Rate  \
# 0    Andhra Pradesh   31-05-2019   Monthly                         3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                         3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                         3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                         3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                         5.17
# ..              ...          ...       ...                          ...
# 763             NaN          NaN       NaN                          NaN
# 764             NaN          NaN       NaN                          NaN
# 765             NaN          NaN       NaN                          NaN
# 766             NaN          NaN       NaN                          NaN
# 767             NaN          NaN       NaN                          NaN
#
#      Estimated Employed  Estimated Labour Participated Rate Region  Day Month  \
# ...

# %%
df.drop(columns=['Frequency'],axis=0,inplace=True)
df
# Out:
#              States         Date  Estimated Unemployment Rate  \
# 0    Andhra Pradesh   31-05-2019                         3.65
# 1    Andhra Pradesh   30-06-2019                         3.05
# 2    Andhra Pradesh   31-07-2019                         3.75
# 3    Andhra Pradesh   31-08-2019                         3.32
# 4    Andhra Pradesh   30-09-2019                         5.17
# ..              ...          ...                          ...
# 763             NaN          NaN                          NaN
# 764             NaN          NaN                          NaN
# 765             NaN          NaN                          NaN
# 766             NaN          NaN                          NaN
# 767             NaN          NaN                          NaN
#
#      Estimated Employed  Estimated Labour Participated Rate Region  Day Month  \
# 0            11999139.0                               43.24  Rural   31    05
# ...

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.show()

# %% [markdown]
# **Analysis** **the** **Data** **by** **Histogram** **plot**

# %%
df.Region.value_counts()
# Out:
# Urban    381
# Rural    359
# Name: Region, dtype: int64

# %%
df.columns
plt.title('Indian Unemployment')
sns.histplot(x="Estimated Employed",hue="Region",data=df)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.title('Indian Unemplyment')
sns.histplot(x="Estimated Unemployment Rate",hue="Region",data=df)
plt.show()

# %%
fg=px.histogram(df,x='States',y='Estimated Unemployment Rate',title='Indian unemployment rate(state-wise)',template='plotly',color='States')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
